# %%
import shutil
import os
from PIL import Image
import PIL
import glob

# %%
source = "/content/drive/MyDrive/upward_trend_bing"
destination = "/content/drive/MyDrive/upward_trend"

files = os.listdir(source)

i = 700
for file in files:
    new_path = shutil.copy(f"{source}/{file}", f"{destination}/{i}.jpg")
    i += 1
    print(new_path)
# Out:
# /content/drive/MyDrive/upward_trend/700.jpg
# /content/drive/MyDrive/upward_trend/701.jpg
# /content/drive/MyDrive/upward_trend/702.jpg
# /content/drive/MyDrive/upward_trend/703.jpg
# /content/drive/MyDrive/upward_trend/704.jpg
# /content/drive/MyDrive/upward_trend/705.jpg
# /content/drive/MyDrive/upward_trend/706.jpg
# /content/drive/MyDrive/upward_trend/707.jpg
# /content/drive/MyDrive/upward_trend/708.jpg
# /content/drive/MyDrive/upward_trend/709.jpg
# /content/drive/MyDrive/upward_trend/710.jpg
# /content/drive/MyDrive/upward_trend/711.jpg
# /content/drive/MyDrive/upward_trend/712.jpg
# /content/drive/MyDrive/upward_trend/713.jpg
# /content/drive/MyDrive/upward_trend/714.jpg
# /content/drive/MyDrive/upward_trend/715.jpg
# /content/drive/MyDrive/upward_trend/716.jpg
# /content/drive/MyDrive/upward_trend/717.jpg
# /content/drive/MyDrive/upward_trend/718.jpg
# /content/drive/MyDrive/upward_trend/719.jpg
# /content/drive/MyDrive/upward_trend/720.jpg
# ...

# %%
source = "/content/drive/MyDrive/upward_trend"

files = os.listdir(source)
for i, file in enumerate(files):
    try:
        image = Image.open(f"{source}/{file}").convert('RGB')
        resized_image = image.resize((256,256))
        resized_image.save(f"/content/drive/MyDrive/upward_trend_resized/{i}.jpeg")
    except:
        continue
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
from os import listdir
from os.path import isfile, join
import os
from PIL import Image
from tqdm.notebook import tqdm

IMAGE_PATH = '/content/drive/MyDrive/upward_trend_resized/'
files = [f for f in listdir(IMAGE_PATH) if isfile(join(IMAGE_PATH, f))]

base_size = (256, 256)
for file in tqdm(files):
  file2 = os.path.join(IMAGE_PATH,file)
  img = Image.open(file2)
  sz = img.size
  if base_size and sz!=base_size:
    print(f"Inconsistant size: {file2}")
  elif img.mode!='RGB':
    print(f"Inconsistant color format: {file2}")
  else:
    base_size = sz
# Out:
#   0%|          | 0/581 [00:00<?, ?it/s]
