# %%
import requests
import shutil
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
url = "https://advance.lexis.com/search/?pdmfid=1516831&crid=2fb68138-1777-4f3b-a900-3caefbf35719&pdsearchterms=AAPL&pdstartin=hlct%3A1%3A1&pdtypeofsearch=searchboxclick&pdsearchtype=SearchBox&pdqttype=and&pdpsf=&pdquerytemplateid=&ecomp=_dJgkgk&earg=pdpsf&prid=6b44962f-cccb-4af7-b024-e22a50d3d933"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.content)

# %%
boxes = soup.findAll(attrs={"class":"doc-title translate"})

# %%
boxes
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=10" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1" name="viewport"/>
# <style>
# </style>
# <title>Lexis® - Sign In | LexisNexis</title>
# <meta content="LexisNexis users sign in here. Click here to login and begin conducting your legal research now." name="description"/>
# <link href="/lnaccess/css/global.css?version=11_1" rel="stylesheet" type="text/css"/>
# <link href="/lnaccess/css/wam.css?version=11_1" rel="stylesheet" type="text/css"/>
# <link href="/lnaccess/css/oauth.css?version=11_1" rel="stylesheet" type="text/css"/>
# <script src="/lnaccess/js/html5shiv.js?version=11_1" type="text/javascript"></script>
# <script src="/lnaccess/js/common.js?version=11_1" type="text/javascript"></script>
# <script src="/lnaccess/js/jquery.min.js?version=11_1" type="text/javascript"></script>
# <script src="/lnaccess/js/validate.js?version=11_1" type="text/javascript"></script>
# ...
